// %%
import com.github.ax_as.datapro.data.DataFiles
import com.github.ax_as.datapro.data.*
import org.jetbrains.kotlinx.dataframe.DataRow
import java.nio.file.Path

fun toLocalPath(file: String) = Path.of("/data/files/output/$file")
val htmlSerproBB = toLocalPath("serpro_vs_bb.html")

val configuration = DisplayConfiguration(
    rowsLimit = null,
    useDarkColorScheme = true,
)

var listaAC =
    DataFrame.concursoSerproObjetivas(DataFiles.objetivas_ac)
        .final_objetivas("AC")
        .final_objetivas_pond()


var listaPPP =
    DataFrame.concursoSerproObjetivas(DataFiles.objetivas_ppp)
        .final_objetivas("PPP")
        .final_objetivas_pond()

var listaPCD =
    DataFrame.concursoSerproObjetivas(DataFiles.objetivas_pcd)
        .final_objetivas("PCD")
        .final_objetivas_pond()


var pratica_ac =
    DataFrame.praticaSerpro(DataFiles.serpro_final_pratica, "AC")
        .add("pos_pratica") { index()+1 }


var pratica_ppp =
    DataFrame.praticaSerpro(DataFiles.serpro_final_pratica_ppp, "PPP")
        .add("pos_pratica") { index()+1 }

var pratica_pcd =
    DataFrame.praticaSerpro(DataFiles.serpro_final_pratica_pcd, "PCD")
        .add("pos_pratica") { index()+1 }

var provisoria_ac =
    DataFrame.praticaSerpro(
        DataFiles.serpro_prov_pratica,
        "AC",
        header = headerPraticaProv
    )
        .add("pos_pratica") { index()+1 }

var provisoria_pcd =
    DataFrame.praticaSerpro(
        DataFiles.serpro_prov_pratica_pcd,
        "PCD",
        header = headerPraticaProv
    )
        .add("pos_pratica") { index()+1 }

var provisoria_ppp =
    DataFrame.praticaSerpro(
        DataFiles.serpro_prov_pratica_ppp,
        "PPP",
        header = headerPraticaProv
    )
        .add("pos_pratica") { index()+1 }


var acComPratica = listaAC
    .add_prova_pratica_prov(provisoria_ac)
    .add_prova_pratica_final(pratica_ac)
    .select(
        "pos_final", "lista", "inscricao", "nome",
        "p1",
        "accb",
        "p2",
        "acce",
        "NF_OBJ",
        "p3",
        "NFC"
    ).removerZeradosPratica()

var pppComPratica = listaPPP
    .add_prova_pratica_prov(provisoria_ppp)
    .add_prova_pratica_final(pratica_ppp)
    .select(
        "pos_final", "lista", "inscricao", "nome",
        "p1",
        "accb",
        "p2",
        "acce",
        "NF_OBJ",
        "p3",
        "NFC"
    ).removerZeradosPratica()

var pcdComPratica = listaPCD
    .add_prova_pratica_prov(provisoria_pcd)
    .add_prova_pratica_final(pratica_pcd)
    .select(
        "pos_final", "lista", "inscricao", "nome",
        "p1",
        "accb",
        "p2",
        "acce",
        "NF_OBJ",
        "p3",
        "NFC"
    ).removerZeradosPratica()

var convocacoes = DataFrame.empty()
val primeiraPpp = 3
val primeiraPcd = 5
val primeiraAc = 1

val listaPpp = ListaAprovados(primeiraPpp, 5, pppComPratica)
val listaPcd = ListaAprovados(primeiraPcd, 5, pcdComPratica)
val listaAc = ListaAprovados(candidatos = acComPratica)

val g = GerenciadorConvocacoes<Convocador<*>>(
    arrayListOf(
        listaPpp,
        listaPcd,
        listaAc
    )
)

var vaga = 1
val conv = mutableListOf<DataRow<*>>()
while (true) {
    val candidato = g.convocar(vaga)
    if (candidato == Convocador.emptyResponse) {
        break
    }
    val rowCandidato = candidato as DataRow<*>
    conv.add(rowCandidato)
   
    vaga ++
}

val df = conv.toDataFrame().distinctBy("nome")
    .add("vaga"){index()+1}.moveToLeft("vaga")

//    .select("lista", "inscricao", "nome", )

df.toDefaultHtml().openInBrowser()
// Out:
// The problem is found in one of the loaded libraries: check library converters (fields callbacks)
// Error compiling code:
// @DataSchema
// interface _DataFrameType6
//
//
// (convocacoes as org.jetbrains.kotlinx.dataframe.DataFrame<*>).cast<_DataFrameType6>()
//
// Errors:
// Line_57.jupyter.kts (5:14 - 16) Parameters must have type annotation
// Line_57.jupyter.kts (5:16 - 16) Expecting comma or ')'
// Line_57.jupyter.kts (5:20 - 21) Parameters must have type annotation
// Line_57.jupyter.kts (5:21 - 21) Expecting comma or ')'
// Line_57.jupyter.kts (5:30 - 31) Parameters must have type annotation
// Line_57.jupyter.kts (5:31 - 31) Expecting comma or ')'
// Line_57.jupyter.kts (5:38 - 39) Parameters must have type annotation
// Line_57.jupyter.kts (5:39 - 39) Expecting comma or ')'
// Line_57.jupyter.kts (5:48 - 49) Parameters must have type annotation
// Line_57.jupyter.kts (5:49 - 49) Expecting comma or ')'
// Line_57.jupyter.kts (5:62 - 63) Expecting an element
//
// org.jetbrains.kotlinx.jupyter.exceptions.ReplLibraryException: The problem is found in one of the loaded libraries: check library converters (fields callbacks)
// 	at org.jetbrains.kotlinx.jupyter.exceptions.CompositeReplExceptionKt.throwLibraryException(CompositeReplException.kt:50)
// 	at org.jetbrains.kotlinx.jupyter.codegen.FieldsProcessorImpl.process(FieldsProcessorImpl.kt:68)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$1.invoke(CellExecutorImpl.kt:97)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$1.invoke(CellExecutorImpl.kt:96)
// 	at org.jetbrains.kotlinx.jupyter.config.LoggingKt.catchAll(logging.kt:42)
// 	at org.jetbrains.kotlinx.jupyter.config.LoggingKt.catchAll$default(logging.kt:41)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute(CellExecutorImpl.kt:96)
// 	at org.jetbrains.kotlinx.jupyter.repl.CellExecutor$DefaultImpls.execute$default(CellExecutor.kt:16)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl$evalEx$1.invoke(repl.kt:496)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl$evalEx$1.invoke(repl.kt:474)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl.withEvalContext(repl.kt:437)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl.evalEx(repl.kt:474)
// 	at org.jetbrains.kotlinx.jupyter.messaging.ProtocolKt$shellMessagesHandler$2$res$1.invoke(protocol.kt:320)
// 	at org.jetbrains.kotlinx.jupyter.messaging.ProtocolKt$shellMessagesHandler$2$res$1.invoke(protocol.kt:314)
// 	at org.jetbrains.kotlinx.jupyter.JupyterExecutorImpl$runExecution$execThread$1.invoke(execution.kt:38)
// 	at org.jetbrains.kotlinx.jupyter.JupyterExecutorImpl$runExecution$execThread$1.invoke(execution.kt:33)
// 	at kotlin.concurrent.ThreadsKt$thread$thread$1.run(Thread.kt:30)
// Caused by: org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: Line_57.jupyter.kts (5:14 - 16) Parameters must have type annotation
// Line_57.jupyter.kts (5:16 - 16) Expecting comma or ')'
// Line_57.jupyter.kts (5:20 - 21) Parameters must have type annotation
// Line_57.jupyter.kts (5:21 - 21) Expecting comma or ')'
// Line_57.jupyter.kts (5:30 - 31) Parameters must have type annotation
// Line_57.jupyter.kts (5:31 - 31) Expecting comma or ')'
// Line_57.jupyter.kts (5:38 - 39) Parameters must have type annotation
// Line_57.jupyter.kts (5:39 - 39) Expecting comma or ')'
// Line_57.jupyter.kts (5:48 - 49) Parameters must have type annotation
// Line_57.jupyter.kts (5:49 - 49) Expecting comma or ')'
// Line_57.jupyter.kts (5:62 - 63) Expecting an element
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:182)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:102)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:78)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$execute$1$result$1.invoke(CellExecutorImpl.kt:76)
// 	at org.jetbrains.kotlinx.jupyter.ReplForJupyterImpl.withHost(repl.kt:681)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute(CellExecutorImpl.kt:76)
// 	at org.jetbrains.kotlinx.jupyter.repl.CellExecutor$DefaultImpls.execute$default(CellExecutor.kt:16)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl$ExecutionContext.execute(CellExecutorImpl.kt:231)
// 	at org.jetbrains.kotlinx.dataframe.jupyter.Integration.execute(Integration.kt:76)
// 	at org.jetbrains.kotlinx.dataframe.jupyter.Integration.execute(Integration.kt:89)
// 	at org.jetbrains.kotlinx.dataframe.jupyter.Integration.updateAnyFrameVariable(Integration.kt:124)
// 	at org.jetbrains.kotlinx.dataframe.jupyter.Integration.access$updateAnyFrameVariable(Integration.kt:66)
// 	at org.jetbrains.kotlinx.dataframe.jupyter.Integration$onLoaded$4.invoke(Integration.kt:280)
// 	at org.jetbrains.kotlinx.dataframe.jupyter.Integration$onLoaded$4.invoke(Integration.kt:275)
// 	at org.jetbrains.kotlinx.jupyter.api.libraries.FieldHandlerFactory.createUpdateExecution$lambda$0(FieldHandlerFactory.kt:38)
// 	at org.jetbrains.kotlinx.jupyter.codegen.FieldsProcessorImplKt.executeEx(FieldsProcessorImpl.kt:88)
// 	at org.jetbrains.kotlinx.jupyter.codegen.FieldsProcessorImplKt.access$executeEx(FieldsProcessorImpl.kt:1)
// 	at org.jetbrains.kotlinx.jupyter.codegen.FieldsProcessorImpl.process(FieldsProcessorImpl.kt:47)
// 	... 15 more
